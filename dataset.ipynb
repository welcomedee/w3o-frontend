# %% [markdown]
# <a href="https://colab.research.google.com/github/welcomedee/w3o-frontend/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
quality =pd.read_csv('/content/drive/MyDrive/dataset/apple_quality.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
quality.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
quality.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
#check the null values in data:
quality.isnull().sum() #returns a Series where each element represents the count of null values in the corresponding column of the quality DataFrame. This is useful for understanding how many missing values exist in each column of
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
#check duplicate values in the data:
quality.duplicated().sum()
# Out:
# 0

# %%
#drop the null values
quality = quality.dropna()
quality.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 312.5+ KB

# %%
quality.drop('A_id',axis=1,inplace=True)
quality.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
quality.info() # it dropped the null valued row so the number of entries in the table drops to 4000 entries from 4001 entires
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         4000 non-null   float64
#  1   Weight       4000 non-null   float64
#  2   Sweetness    4000 non-null   float64
#  3   Crunchiness  4000 non-null   float64
#  4   Juiciness    4000 non-null   float64
#  5   Ripeness     4000 non-null   float64
#  6   Acidity      4000 non-null   object
#  7   Quality      4000 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 281.2+ KB

# %%
#Show the number of bad apples and the good apples in the data:
compare = quality['Quality'].value_counts()
compare
# Out:
# good    2004
# bad     1996
# Name: Quality, dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a bar plot with custom colors for 'good' and 'bad'
plt.bar(compare.index, compare, color=['green', 'red'])

# Add labels and title
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Good vs Bad Quality')

# Show the plot
plt.show()

# %% [markdown]
# Logistic Regression with Apple Quality Dataset

# %%
quality.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
quality.Acidity.value_counts()
# Out:
# -0.491590483    1
# 1.006877454     1
# -0.132407603    1
# 1.223084441     1
# 2.190636353     1
#                ..
# -3.873112715    1
# -0.08899782     1
# -0.3815496      1
# 4.67363368      1
# 1.599796456     1
# Name: Acidity, Length: 4000, dtype: int64

# %%
import numpy as np
y = [0 if each == 'bad' else 1 for each in quality.loc[:,'Quality']]
x = quality.loc[:,quality.columns != 'Quality']
x = np.array(x, dtype=float)
x = pd.DataFrame(x)
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4000 non-null   float64
#  1   1       4000 non-null   float64
#  2   2       4000 non-null   float64
#  3   3       4000 non-null   float64
#  4   4       4000 non-null   float64
#  5   5       4000 non-null   float64
#  6   6       4000 non-null   float64
# dtypes: float64(7)
# memory usage: 218.9 KB

# %%
x = (x - np.min(x))/(np.max(x)-np.min(x))
x.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# (4000, 7)

# %%
x.info()
x.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4000 non-null   float64
#  1   1       4000 non-null   float64
#  2   2       4000 non-null   float64
#  3   3       4000 non-null   float64
#  4   4       4000 non-null   float64
#  5   5       4000 non-null   float64
#  6   6       4000 non-null   float64
# dtypes: float64(7)
# memory usage: 218.9 KB
# (4000, 7)

# %%
y= np.array(y).reshape(-1,1)
y.shape
# Out:
# (4000, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train = x_train.T
x_test = x_test.T
y_train = y_train.T
y_test = y_test.T

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7, 3200)
# (7, 800)
# (1, 3200)
# (1, 800)

# %%
def initialize_weights_and_bias(dimension):
    w = np.full((dimension,1),0.01)
    b = 0.0
    return w,b

# %%
def sigmoid(z):
    y_head = 1/(1+np.exp(-z))
    return y_head
    #gradient descent and optimization

# %%
def forward_backward_propagation(w,b,x_train,y_train):
    #forward
    z = np.dot(w.T,x_train)+b
    y_head = sigmoid(z)

    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling

        #backward

    derivative_weight = (np.dot(x_train,((y_head-y_train).T)))/x_train.shape[1] # x_train.shape[1]  is for scaling
    derivative_bias = np.sum(y_head-y_train)/x_train.shape[1]                 # x_train.shape[1]  is for scaling

    gradients = {'derivative_weight':derivative_weight,'derivative_bias':derivative_bias}

    return cost,gradients

# %%
def update(w,b,x_train,y_train,learning_rate,number_of_iterations):
    index = []
    cost_list = []
    cost_list2 = []

    for i in range(number_of_iterations):
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        if i % 10 == 0:
            cost_list2.append(cost)
            index.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
        w = w - learning_rate * gradients['derivative_weight']
        b = b - learning_rate * gradients['derivative_bias']

    parameters = {'weight':w,'bias':b}

    plt.plot(index,cost_list2)
    plt.xticks(index,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    return parameters, gradients, cost_list
# gradient descent optimization for a logistic regression model

# %%
def predict(w,b,x_test):
    z = np.dot(w.T,x_test)+b
    y_head = sigmoid(z)
    Y_prediction = np.zeros((1,x_test.shape[1]))

    for i in range(z.shape[1]):
        if z[0,i] <= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1
    return Y_prediction

# %%
def logistic_regression(x_train,y_train,x_test,y_test,learning_rate,number_of_iterations):
    dimension = x_train.shape[0]
    w,b = initialize_weights_and_bias(dimension)
    parameters, gradients, cost_list = update(w,b,x_train,y_train,learning_rate,number_of_iterations)

    y_prediction_test = predict(parameters['weight'],parameters['bias'],x_test)
    y_prediction_train = predict(parameters['weight'],parameters['bias'],x_train)

    print(cost_list)

    print('Test data accuracy  : {} %'.format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    print('Train data accuracy : {} %'.format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))

# %%
logistic_regression(x_train,y_train,x_test,y_test,learning_rate=0.01,number_of_iterations=150)
# Out:
# Cost after iteration 0: 0.692921
# Cost after iteration 10: 0.692799
# Cost after iteration 20: 0.692677
# Cost after iteration 30: 0.692556
# Cost after iteration 40: 0.692434
# Cost after iteration 50: 0.692313
# Cost after iteration 60: 0.692191
# Cost after iteration 70: 0.692070
# Cost after iteration 80: 0.691949
# Cost after iteration 90: 0.691828
# Cost after iteration 100: 0.691707
# Cost after iteration 110: 0.691587
# Cost after iteration 120: 0.691466
# Cost after iteration 130: 0.691346
# Cost after iteration 140: 0.691226
# [0.6929214822060963, 0.6929092603879559, 0.692897040393799, 0.6928848222166019, 0.6928726058494327, 0.6928603912854503, 0.6928481785179033, 0.6928359675401279, 0.6928237583455484, 0.6928115509276742, 0.6927993452800995, 0.6927871413965024, 0.6927749392706438, 0.6927627388963654, 0.6927505402675896, 0.6927383433783179, 0.6927261482226299, 0.6927139547946826, 0.6927017630887087, 0.6926895730990168, 0.6926773848199886, 0.6926651982460793, 0.6926530133718165, 0.6926408301917982, 0.6926286487006935, 0.6926164688932402, 0.6926042907642446, 0.6925921143085801, 0.6925799395211868, 0.692567766397071, 0.6925555949313028, 0.6925434251190167, 0.6925312569554098, 0.6925190904357421, 0.6925069255553344, 0.6924947623095682, 0.6924826006938841, 0.6924704407037828, 0.692458282334822, 0.6924461255826178, 0.6924339704428416, 0.6924218169112217, 0.6924096649835412, 0.6923975146556368, 0.6923853659234002, 0.6923732187827747, 0.6923610732297563, 0.6923489292603926, 0.6923367868707819, 0.6923246460570724, 0.6923125068154622, 0.6923003691421974, 0.6922882330335731, 0.6922760984859315, 0.6922639654956615, 0.6922518340591982, 0.6922397041730229, 0.6922275758336611, 0.6922154490376832, 0.6922033237817032, 0.6921912000623783, 0.6921790778764085, 0.6921669572205355, 0.6921548380915429, 0.692142720486255, 0.6921306044015365, 0.6921184898342922, 0.6921063767814658, 0.6920942652400401, 0.6920821552070362, 0.6920700466795126, 0.6920579396545654, 0.6920458341293275, 0.6920337301009678, 0.692021627566691, 0.6920095265237373, 0.6919974269693817, 0.6919853289009332, 0.6919732323157354, 0.6919611372111645, 0.6919490435846302, 0.6919369514335747, 0.6919248607554727, 0.6919127715478297, 0.6919006838081831, 0.691888597534101, 0.6918765127231822, 0.6918644293730548, 0.6918523474813774, 0.6918402670458371, 0.6918281880641505, 0.6918161105340621, 0.6918040344533445, 0.6917919598197986, 0.691779886631252, 0.6917678148855595, 0.6917557445806025, 0.6917436757142884, 0.6917316082845509, 0.6917195422893491, 0.691707477726667, 0.691695414594514, 0.6916833528909235, 0.6916712926139534, 0.6916592337616855, 0.691647176332225, 0.6916351203237006, 0.6916230657342638, 0.6916110125620882, 0.6915989608053708, 0.6915869104623298, 0.6915748615312054, 0.691562814010259, 0.6915507678977738, 0.691538723192053, 0.6915266798914215, 0.6915146379942229, 0.6915025974988225, 0.6914905584036045, 0.6914785207069726, 0.69146648440735, 0.6914544495031789, 0.6914424159929201, 0.691430383875053, 0.6914183531480751, 0.6914063238105022, 0.6913942958608671, 0.6913822692977212, 0.6913702441196322, 0.6913582203251856, 0.6913461979129834, 0.691334176881644, 0.6913221572298024, 0.6913101389561099, 0.6912981220592332, 0.6912861065378558, 0.6912740923906753, 0.6912620796164057, 0.6912500682137758, 0.6912380581815291, 0.6912260495184238, 0.6912140422232329, 0.6912020362947436, 0.6911900317317571, 0.6911780285330886, 0.6911660266975672, 0.6911540262240353, 0.6911420271113488, 0.6911300293583768, 0.6911180329640014]
# Test data accuracy  : 50.125 %
# Train data accuracy : 49.84375 %

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x_train.T,y_train.T)
print('Test data accuracy  : {} %'.format(logreg.score(x_test.T,y_test.T)))
print('Train data accuracy : {} %'.format(logreg.score(x_train.T,y_train.T)))
# Out:
# Test data accuracy  : 0.75625 %
# Train data accuracy : 0.7471875 %
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# outliers

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(quality['Size'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.title('Histogram of Size Values')

# Show the plot
plt.show()

# %%
#The plot clearly show that we have much number of outliers in the column of apples weights
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(quality['Weight'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Weight')
plt.ylabel('Values')
plt.title('Histogram of Size Values')

# Show the plot
plt.show()

# %%
#The plot clearly show that we have much number of outliers in the column of apples swe
# Create a histogram
plt.hist(quality['Sweetness'], bins=10, color='skyblue', edgecolor='black')
# Add labels and title
plt.xlabel('Sweetness')
plt.ylabel('Values')
plt.title('Histogram of Sweetness')

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(quality['Crunchiness'], bins=10, color='skyblue', edgecolor='black')

plt.xlabel('Crunchiness')
plt.ylabel('Values')
plt.title('Histogram of Crunchiness')

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(quality['Juiciness'], bins=10, color='skyblue', edgecolor='black')


# Add labels and title
plt.xlabel('Juiciness')
plt.ylabel('Values')
plt.title('Histogram of Juiciness')

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(quality['Ripeness'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Ripeness')
plt.ylabel('Values')
plt.title('Histogram of Ripeness')

# Show the plot
plt.show()

# %%
#remove the outliers:
import numpy as np
filter_data=quality.iloc[:,[0,1,2,3,4,5]]
filter_data.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849

# %%
'''-In this cell we make a new data frame and take the columns have outliers to remove all outliers in each column or reduce it we can show that in the coming cells

-We use the inter_quartile range (IQR) to remove the outliers:'''
for column in filter_data.columns:
    Q1 = filter_data[column].quantile(0.25)
    Q3 = filter_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    quality[column] = filter_data[(filter_data[column] >= lower_bound) & (filter_data[column] <= upper_bound)][column]

# %%
quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         3978 non-null   float64
#  1   Weight       3946 non-null   float64
#  2   Sweetness    3968 non-null   float64
#  3   Crunchiness  3953 non-null   float64
#  4   Juiciness    3968 non-null   float64
#  5   Ripeness     3976 non-null   float64
#  6   Acidity      4000 non-null   object
#  7   Quality      4000 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 281.2+ KB

# %%
import matplotlib.pyplot as plt

# Create a histogram for 'Size'
plt.hist(quality['Size'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.title('Histogram of Size')

# Show the plot
plt.show()

# Create a histogram for 'Weight'
plt.hist(quality['Weight'], bins=10, color='lightgreen', edgecolor='black')

# Add labels and title
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.title('Histogram of Weight')

# Show the plot
plt.show()

# Create a histogram for 'Sweetness'
plt.hist(quality['Sweetness'], bins=10, color='lightcoral', edgecolor='black')

# Add labels and title
plt.xlabel('Sweetness')
plt.ylabel('Frequency')
plt.title('Histogram of Sweetness')

# Show the plot
plt.show()

# Create a histogram for 'Crunchiness'
plt.hist(quality['Crunchiness'], bins=10, color='lightblue', edgecolor='black')

# Add labels and title
plt.xlabel('Crunchiness')
plt.ylabel('Frequency')
plt.title('Histogram of Crunchiness')

# Show the plot
plt.show()

# Create a histogram for 'Juiciness'
plt.hist(quality['Juiciness'], bins=10, color='lightsalmon', edgecolor='black')

# Add labels and title
plt.xlabel('Juiciness')
plt.ylabel('Frequency')
plt.title('Histogram of Juiciness')

# Show the plot
plt.show()

# Create a histogram for 'Ripeness'
plt.hist(quality['Ripeness'], bins=10, color='lightyellow', edgecolor='black')

# Add labels and title
plt.xlabel('Ripeness')
plt.ylabel('Frequency')
plt.title('Histogram of Ripeness')

# Show the plot
plt.show()

# %%
quality.describe()
# Out:
#               Size       Weight    Sweetness  Crunchiness    Juiciness  \
# count  3978.000000  3946.000000  3968.000000  3953.000000  3968.000000
# mean     -0.502679    -0.999523    -0.485084     0.983335     0.518410
# std       1.882759     1.511450     1.884943     1.318371     1.865536
# min      -5.692093    -5.058679    -5.548641    -2.683859    -4.756731
# 25%      -1.805829    -1.998099    -1.733598     0.079945    -0.789481
# 50%      -0.513703    -0.986963    -0.509611     0.997933     0.536251
# 75%       0.790415     0.013626     0.777370     1.882414     1.825459
# max       4.649923     3.081538     4.606386     4.591936     5.598023
#
#           Ripeness
# count  3976.000000
# mean      0.505766
# std       1.830208
# min      -4.471210
# 25%      -0.760710
# 50%       0.506934
# 75%       1.756264
# max       5.553256

# %%
plt.hist(quality['Size'], bins=150, color='green', edgecolor='black')
plt.xlabel('size values')
plt.ylabel('Frequency')
plt.title('size distribution')

# Show the plot
plt.show()

# %% [markdown]
# 1-All apples in the data have range size from -6 to 4
#
# 2-70 apples in the data have range size -2 to -1
#
# 3-The mean of the apple size equals to -0.502679
#
# 4-Maximum size is equals to 4.649923
#
# 5-The number of apples have Size are 3978.000000

# %%
plt.hist(quality['Weight'], bins=150, color='green', edgecolor='black')
 # Add labels and title
plt.xlabel('Weight values')
plt.ylabel('Frequency')
plt.title('Weight distribution')

# Show the plot
plt.show()

# %% [markdown]
# 1-All apples in the data have range weights from -5 to 3
#
# 2-Maximum numbers of apples in the data have range size -2 to 1
#
# 3-The mean of the apple size equals to -0.999523
#
# 4-Maximum weight is equals to 3.081538
#
# 5-The number of apples have Weight are 3946.000000

# %%
plt.hist(quality['Sweetness'], bins=150, color='green', edgecolor='black')
 # Add labels and title
plt.xlabel('Sweetness values')
plt.ylabel('Frequency')
plt.title('Sweetness distribution')

# Show the plot
plt.show()

# %% [markdown]
# 1-The sweetness of the all apples have values range from -5.548641 to 4.606386
#
# 2-The count of more than 60 apples have sweetness from -1.5 to 0.5
#
# 3-The mean of the sweetness is equal to -0.485084
#
# 4-We can assume the sweetness of most apples in range of -2 to 2
#
# 5-The number of apples have Sweetness are 3968.000000
#
# 6-From the data we can assume that the many apples not sweetness

# %%
plt.hist(quality['Crunchiness'], bins=150, color='green', edgecolor='black')
 # Add labels and title
plt.xlabel('Crunchiness values')
plt.ylabel('Frequency')
plt.title('Crunchiness distribution')

# Show the plot
plt.show()

# %% [markdown]
# 1-The Crunchiness of the all apples have values range from -2.683859 to 4.591936
#
# 2-The count of more than 65 apples have Crunchiness from 0.5 to 1.7
#
# 3-The mean of the Crunchiness is equal to 0.983335
#
# 4-We can assume the Crunchiness of the most numbers of apples in range of 0 to 2.5
#
# 5-The number of apples have ripeness are 3953.000000
#
# 6-From the data we can assume that the many apples Crunchiness

# %%
plt.hist(quality['Juiciness'], bins=150, color='green', edgecolor='black')
 # Add labels and title
plt.xlabel('Juiciness values')
plt.ylabel('Frequency')
plt.title('Juiciness distribution')

# Show the plot
plt.show()

# %% [markdown]
# 1-The Juiciness of the all apples have values range from -4.756731to 5.598023
#
# 2-The mean of the Juiciness is equal to 0.518410
#
# 3-We can assume the Juiciness of the most numbers of apples in range of -0.5 to 2.5
#
# 4-The number of apples have ripeness are 3968.000000
#
# 5-From the data we can assume that the many apples Juiciness

# %%
plt.hist(quality['Ripeness'], bins=150, color='green', edgecolor='black')
 # Add labels and title
plt.xlabel('Ripeness values')
plt.ylabel('Frequency')
plt.title('Ripeness distribution')

# Show the plot
plt.show()

# %% [markdown]
# 1-The Ripeness of the all apples have values range from -4.471210to 5.553256
#
# 2-The mean of the Ripeness is equal to 0.505766
#
# 3-We can assume the Ripeness of the most numbers of apples in range of 0.5 to 1.5
#
# 4-The number of apples have ripeness are 3976.000000
#
# 5-From the data we can assume that the many apples Ripeness

# %%
quality.describe()
#-The above cell express the all values in each column you can show an values you need to know
# Out:
#               Size       Weight    Sweetness  Crunchiness    Juiciness  \
# count  3978.000000  3946.000000  3968.000000  3953.000000  3968.000000
# mean     -0.502679    -0.999523    -0.485084     0.983335     0.518410
# std       1.882759     1.511450     1.884943     1.318371     1.865536
# min      -5.692093    -5.058679    -5.548641    -2.683859    -4.756731
# 25%      -1.805829    -1.998099    -1.733598     0.079945    -0.789481
# 50%      -0.513703    -0.986963    -0.509611     0.997933     0.536251
# 75%       0.790415     0.013626     0.777370     1.882414     1.825459
# max       4.649923     3.081538     4.606386     4.591936     5.598023
#
#           Ripeness
# count  3976.000000
# mean      0.505766
# std       1.830208
# min      -4.471210
# 25%      -0.760710
# 50%       0.506934
# 75%       1.756264
# max       5.553256

# %%
#that is bad column , I will drop it:
quality.drop('Acidity',axis=1,inplace=True)
quality.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness Quality
# 0 -3.970049 -2.512336        NaN    -1.012009   1.844900  0.329840    good
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530    good
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033     bad
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761    good
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849    good

# %%
correalation=quality.iloc[:,[0,1,2,3,4,5]]
correalation
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 0    -3.970049 -2.512336        NaN    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
# [4000 rows x 6 columns]

# %%
correalation.corr()
# Out:
#                  Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# Size         1.000000 -0.142270  -0.316384     0.167966  -0.023137 -0.141365
# Weight      -0.142270  1.000000  -0.122553    -0.088520  -0.091578 -0.225686
# Sweetness   -0.316384 -0.122553   1.000000    -0.014351   0.090149 -0.261095
# Crunchiness  0.167966 -0.088520  -0.014351     1.000000  -0.231174 -0.184367
# Juiciness   -0.023137 -0.091578   0.090149    -0.231174   1.000000 -0.109068
# Ripeness    -0.141365 -0.225686  -0.261095    -0.184367  -0.109068  1.000000

# %%
#The plot is express the correlation between samples in the data
import seaborn as sns
realtion=correalation.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(realtion ,annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# matplot.lib
# pandas
# seaborn
# numpy
# sklearn.model_selection
